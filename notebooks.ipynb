# %%
from dnn_test import *

# %%
tester = DNNtest()
tester.all_test()
# Out:
# Comparing image/base/1.png with image/ng/1.png
# image/base/1.png image/ng/1.png
# result_temp 223
# result_final_matrix =  169
# ...
